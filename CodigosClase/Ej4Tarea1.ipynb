# %%
import math as mt
import numpy as np
import matplotlib.pyplot as pl

# %%
# a1 = 15.8
# a2 = 18.3
# a3 = 0.714
# a4 = 23.2
# # a5 = ???

# %%
def EnergiaEnlace(A,Z):

    a1 = 15.8
    a2 = 18.3
    a3 = 0.714
    a4 = 23.2
    a5 = 0
    

    if (A % 2 == 0) and (Z % 2 == 0):
        a5 = 12
    elif (A % 2 == 0) and (Z % 2 != 0):
        a5 = -12 
    elif (A % 2 != 0):
        a5 = 0

    B = a1*A - a2*(A**(2/3)) - a3*((Z**2)/(A**(1/3))) - a4*(((A-2*Z)**2)/A)+ a5/(A**(1/2))
        
    return B

def EnergiaEnlace2(A,Z):

    a1 = 15.8
    a2 = 18.3
    a3 = 0.714
    a4 = 23.2
    a5 = 0
    

    if (A % 2 == 0) and (Z % 2 == 0):
        a5 = 12
    elif (A % 2 == 0) and (Z % 2 != 0):
        a5 = -12 
    elif (A % 2 != 0):
        a5 = 0

    B = a1*A - a2*(A**(2/3)) - a3*((Z**2)/(A**(1/3))) - a4*(((A-2*Z)**2)/A)+ a5/(A**(1/2))
        
    return B/A

def EnergiaEnlace3(Z):

    Energias = []

    a1 = 15.8
    a2 = 18.3
    a3 = 0.714
    a4 = 23.2
    a5 = 0
    
    for A in range(Z,3*Z + 1):    
        
        if (A % 2 == 0) and (Z % 2 == 0):
            a5 = 12
        elif (A % 2 == 0) and (Z % 2 != 0):
            a5 = -12 
        elif (A % 2 != 0):
            a5 = 0
    
        B = a1*A - a2*(A**(2/3)) - a3*((Z**2)/(A**(1/3))) - a4*(((A-2*Z)**2)/A)+ a5/(A**(1/2))

        Energias.append(B/A)
        # print(B/A)
        
        maximo = max(Energias)

    # print(Energias)

    return maximo


def EnergiaEnlace4():

    a1 = 15.8
    a2 = 18.3
    a3 = 0.714
    a4 = 23.2
    a5 = 0

    Emax = []
    # Zmax = []

    for Z in range(1,101):

        Energias = []
        
        for A in range(Z,3*Z + 1):    
            
            if (A % 2 == 0) and (Z % 2 == 0):
                a5 = 12
            elif (A % 2 == 0) and (Z % 2 != 0):
                a5 = -12 
            elif (A % 2 != 0):
                a5 = 0
        
            B = a1*A - a2*(A**(2/3)) - a3*((Z**2)/(A**(1/3))) - a4*(((A-2*Z)**2)/A)+ a5/(A**(1/2))    
            Energias.append(B/A)  
            
        maximo = max(Energias)

        Emax.append(maximo)
        # Zmax.append(Z)
        
        print("Z = ",Z,"Energia maxima =",maximo)

    ElMasMax = max(Emax)
    ElZmasMax = np.argmax(Emax)

    return ElMasMax,int(ElZmasMax+1)

# %%
# np.argmax?

# %%
A = 58
Z = 28
# EnergiaEnlace2(A,Z)
# EnergiaEnlace3(Z)
EnergiaEnlace4()
# Out:
# Z =  1 Energia maxima = 0.36869091831015827
# Z =  2 Energia maxima = 5.321930578649441
# Z =  3 Energia maxima = 5.280168164356119
# Z =  4 Energia maxima = 6.466330085889912
# Z =  5 Energia maxima = 6.650123444727665
# Z =  6 Energia maxima = 7.200918138809924
# Z =  7 Energia maxima = 7.330860591990981
# Z =  8 Energia maxima = 7.719275577459026
# Z =  9 Energia maxima = 7.73697768275634
# Z =  10 Energia maxima = 8.035350864715019
# Z =  11 Energia maxima = 8.025554739665797
# Z =  12 Energia maxima = 8.241172535624845
# Z =  13 Energia maxima = 8.240988355754636
# Z =  14 Energia maxima = 8.37916169002579
# Z =  15 Energia maxima = 8.38521415855582
# Z =  16 Energia maxima = 8.489230168218935
# Z =  17 Energia maxima = 8.48201495174352
# Z =  18 Energia maxima = 8.573405285254953
# Z =  19 Energia maxima = 8.551826855569242
# Z =  20 Energia maxima = 8.627152167121634
# Z =  21 Energia maxima = 8.610130576802973
# Z =  22 Energia maxima = 8.6585154571142
# Z =  23 Energia maxima = 8.645234048730842
# Z =  24 Energia maxima = 8.687306583887372
# Z =  25 Energia maxima = 8.662703971015583
# Z =  26 Energia maxima = 8.701432576808987
# Z =  27 Energia maxima = 8.678053678353882
# Z =  28 Energia maxima = 8.70245768367189
# Z =  29 Energia maxima = 8.681907349580422
# Z =  30 Energia maxima = 8.701580328486784
# Z =  31 Energia maxima = 8.675012598311142
# Z =  32 Energia maxima = 8.693433639739787
# Z =  33 Energia maxima = 8.668156247337208
# Z =  34 Energia maxima = 8.67683411103597
# Z =  35 Energia maxima = 8.653727479263061
# Z =  36 Energia maxima = 8.66141248935323
# Z =  37 Energia maxima = 8.633940444065898
# Z =  38 Energia maxima = 8.639441275530453
# Z =  39 Energia maxima = 8.613815033672552
# Z =  40 Energia maxima = 8.614514461544127
# Z =  41 Energia maxima = 8.587741675710747
# Z =  42 Energia maxima = 8.588337807352417
# Z =  43 Energia maxima = 8.561488033970447
# Z =  44 Energia maxima = 8.557428804696526
# Z =  45 Energia maxima = 8.531857077904819
# Z =  46 Energia maxima = 8.52785864674169
# Z =  47 Energia maxima = 8.500490244095234
# Z =  48 Energia maxima = 8.4940569666179
# Z =  49 Energia maxima = 8.46797678166812
# Z =  50 Energia maxima = 8.460713172533021
# Z =  51 Energia maxima = 8.433224407343122
# Z =  52 Energia maxima = 8.424696665334825
# Z =  53 Energia maxima = 8.398332486638505
# Z =  54 Energia maxima = 8.38868945344295
# Z =  55 Energia maxima = 8.361310553455423
# Z =  56 Energia maxima = 8.350819725669146
# Z =  57 Energia maxima = 8.32443069811602
# Z =  58 Energia maxima = 8.313019639868703
# Z =  59 Energia maxima = 8.285884693887583
# Z =  60 Energia maxima = 8.273583815729522
# Z =  61 Energia maxima = 8.247327458286065
# Z =  62 Energia maxima = 8.234582872513133
# Z =  63 Energia maxima = 8.207769087134613
# Z =  64 Energia maxima = 8.193813966434627
# Z =  65 Energia maxima = 8.167786207290451
# Z =  66 Energia maxima = 8.154024477520512
# Z =  67 Energia maxima = 8.127574530301825
# Z =  68 Energia maxima = 8.11278037767185
# Z =  69 Energia maxima = 8.086373082934724
# Z =  70 Energia maxima = 8.071829365612306
# Z =  71 Energia maxima = 8.045764583108769
# Z =  72 Energia maxima = 8.030368571593026
# Z =  73 Energia maxima = 8.004105311543137
# Z =  74 Energia maxima = 7.988369073415251
# Z =  75 Energia maxima = 7.962697427019249
# Z =  76 Energia maxima = 7.946838055684514
# Z =  77 Energia maxima = 7.921016888554693
# Z =  78 Energia maxima = 7.904575879934101
# Z =  79 Energia maxima = 7.87868400232803
# Z =  80 Energia maxima = 7.862438691993173
# Z =  81 Energia maxima = 7.837047201045294
# Z =  82 Energia maxima = 7.82033857608665
# Z =  83 Energia maxima = 7.794899333942829
# Z =  84 Energia maxima = 7.777785761025879
# Z =  85 Energia maxima = 7.75239433360284
# Z =  86 Energia maxima = 7.735485475322138
# Z =  87 Energia maxima = 7.710478810144077
# Z =  88 Energia maxima = 7.693222175964613
# Z =  89 Energia maxima = 7.668228396728228
# Z =  90 Energia maxima = 7.65068598823387
# Z =  91 Energia maxima = 7.625739835440575
# Z =  92 Energia maxima = 7.608214013689897
# Z =  93 Energia maxima = 7.583639834526779
# Z =  94 Energia maxima = 7.566035830526522
# Z =  95 Energia maxima = 7.5415108314640555
# Z =  96 Energia maxima = 7.523703637516345
# Z =  97 Energia maxima = 7.499251800171257
# Z =  98 Energia maxima = 7.481279349508352
# Z =  99 Energia maxima = 7.456937323389022
# Z =  100 Energia maxima = 7.439122944429214
# (8.70245768367189, 28)
